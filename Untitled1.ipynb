# %%
from getData import *
from plot import *

# %%
neuron_matrix = getNeuronMatrix('Snudda/networks/tinySim')
dspn_ID, ispn_ID, lts_ID, fs_ID, chin_ID = getNeuronSubMatrixes(neuron_matrix)
voltage, time = getVolts('Snudda/networks/tinySim/simulation/volt.txt')
plotTraces(voltage,time,dspn_ID,'R')
plotNeuronalDistribution(neuron_matrix)
spk = getSpikes('Snudda/networks/tinySim/simulation/network-output-spikes-666.txt')
dspnspikes = getSubSpikes(spk,neuron_matrix)

# %%
plotNeuronalDistribution('NEURON-data/net_1000')
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py:395: MatplotlibDeprecationWarning:
# The is_last_row function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_last_row() instead.
#   if ax.is_last_row():

# %%
plotNeuronalDistribution('NEURON-data/net_100')
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py:395: MatplotlibDeprecationWarning:
# The is_last_row function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_last_row() instead.
#   if ax.is_last_row():

# %%
plotTraces(voltage,time,dspn_ID,'F', dspnspikes)
# Out:
# Plotting the traces of the following neurons :  [67, 16, 66, 84, 54]
# ()

# %%
plotTraces('NEURON-data/net_100','R')
# Out:
# Plotting the traces of the following neurons :  [81, 37, 70, 35, 24]
# Plotting the traces of the following neurons :  [83, 5, 50, 47, 75]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-cc9c75ad4253> in <module>
# ----> 1 plotTraces('NEURON-data/net_100','R')
#
# ~/BasalGanglia/plot.py in plotTraces(folder_path, mode, spike_dict)
#      63                 plt.figure()
#      64                 for j in range(0, len(submatrixes[j])):
# ---> 65                     plt.plot(time, voltage_matrix[submatrixes[i][j]], color = colors[i])
#      66                 plt.show()
#      67
#
# IndexError: list index out of range

# %%
plotRaster('NEURON-data/net_1000',1000)

# %%
plotRaster('NEURON-data/net_10000',10000)
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:134: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plotRaster('NEURON-data/net_100',100)

# %%
plotTraces('NEURON-data/net_100', 'R')
# Out:
# Plotting the traces of the following neurons :  [30, 92, 0, 67, 17]
# Plotting the traces of the following neurons :  [47, 29, 7, 11, 26]
# ()
